# %%
#comment
#this is a comment

# %% [markdown]
# Variables

# %%
name="Anjali"

# %%
print(name)
# Out:
# Anjali

# %%
name="heee"
print(name)
# Out:
# heee

# %%
#Dynamic Typing --->need not to declare the type of variable(python,PHP)
#static typing--->need to declare type of variable(c,c++,java)
#Dynamic binding-->one variable can be assigned many times

# %% [markdown]
# Keywords and identifiers

# %%
#python is case sensitive programming language

# %%
import keyword  #python has 33 keywords
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#identifiers can only start with alphabet or _
